# %%
from IPython.display import clear_output
set_password = 'Password.txt'
login_name = 'User_name.txt'
phy_file_ud = 'Phyud.txt'
phy_file = 'Phy.txt'
chem_file = 'Chem.txt'
phy_chap_names = 'PChap.txt'
print('For the following question enter 0 for NO and 1 for YES !!')

while True:
    ask = input('Are you visiting for the first time? ')
    if ask == '0' or ask == '1':
        ask = int(ask)
        break
    else:
        print('Enter a valid input: 0 or 1')

if ask == 1:
    def SignUp(): # sign up if new to this website!!
        User_name = input('Enter your Name : ')
        while True :
         key = input('Create a password :')
         with open(login_name,'w') as file1:                           # writes login name
            saved_User_name = file1.write(User_name)                   # writes password
         with open(set_password,'w') as file2 :
            saved_password = file2.write(key)
         
         if ((User_name in key) and (len(key) < 8) and  key.islower()) :  # error if , username in pwd aand length of pwd<8 and all keys are lower case
            continue
         elif ((User_name in key) and (len(key) < 8)) :                   # SHOWS ERROR
            print('ERRORS : ENTER A PASSWORD THAT DOESN\'T CONTAIN YOUR NAME\n  ENTER A PASSWORD THAT HAS ATLEAST 8 KEYS ')
            continue
         elif ((len(key) < 8) and key.islower()) :                        # SHOWS ERROR
            print('ERRORS :ENTER A PASSWORD THAT HAS ATLEAST 8 KEYS\n  PLS ENTER A PASSWORD THAT CONTAINS AT LEAST 1 UPPERCASE LETTER ')
            continue
         elif (key.islower() and (User_name in key) ) :                   # SHOWS ERROR
            print('ERRORS : PLS ENTER A PASSWORD THAT CONTAINS AT LEAST 1 UPPERCASE LETTER\n ENTER A PASSWORD THAT DOESN\'T CONTAIN YOUR NAME ')
            continue
         elif User_name in key :                                          # SHOWS ERROR
            print('ERROR : ENTER A PASSWORD THAT DOESN\'T CONTAIN YOUR NAME , FOR SECURITY REASONS !! ')
            continue     
         elif len(key) < 8:                                              # SHOWS ERROR
            print('ERROR : ENTER A PASSWORD THAT HAS ATLEAST 8 KEYS , FOR SAFETY !')
            continue
         elif  key.islower() :                                           # SHOWS ERROR
            print('ERROR : PLS ENTER A PASSWORD THAT CONTAINS AT LEAST 1 UPPERCASE LETTER , FOR SAFETY !')
            continue
         elif key.isdigit() :                                             # SHOWS ERROR
            print('ERROR : ALL THE KEYS CAN\'T BE NUMBERS !')
            continue
         elif key.isalpha() :                                            # SHOWS ERROR
            print('ERROR : ALL THE KEYS CAN\'T BE SYMBOLS !!')
            continue
         else:                                                           # SHOWS ERROR
            print(f' Thank You {User_name} for signing up ...!!')
         return User_name , key
    User_name, key = SignUp()
    
    def show_MPC() :                                                      # DEFINES FUNCTION THAT WILL SHOWS THE MPC SECTION
         print(f'Welcome {User_name} to the ultimate resource for JEE materials!! ')
         sub_select = input('SELECT YOUR REQUIRED SUBJECT AS M,P,C  : ').lower()
         if sub_select[0] == 'p' :
           with open('phy_chap_names.txt', 'w') as file3:
               file3.write("1   UNITS AND MEASUREMENT \n")
               file3.write("2   MOTION IN 1 D  \n")
               file3.write("3   MOTION IN 2 D\n")
               file3.write("4   CIRCULAR MOTION IN KINEMATICS \n")
           with open('phy_chap_names.txt', 'r') as file3:
               phy_chapters = file3.readlines()
               for line in phy_chapters:
                   print(line.strip())
               chapter_choice_phy = int(input('Choose your chapter: '))  # ask only once
               if chapter_choice_phy == 1 : 
                clear_output()
                with open('Phyud.txt','r') as file4 :
                   phy_file_ud_content = file4.readlines()
                   for line in phy_file_ud_content :
                       print(line.strip())
               elif  chapter_choice_phy == 2 :
                clear_output()
                with open('Phy1d.txt','r') as file4 :
                   phy_file_1d_content = file4.readlines()
                   for line in phy_file_1d_content :
                       print(line.strip())
               elif chapter_choice_phy == 3 :
                  clear_output()
                  with open('Phy2d.txt','r') as file4 :
                   phy_file_2d_content = file4.readlines()
                   for line in phy_file_2d_content :
                       print(line.strip())

               # If you want to write the content read from file3 to file4, open file4 in append mode
          

    show_MPC()
# Out:
# 2. Motion in a Straight Line
#
# A.
# Motion
# 1.   If an object changes its position with respect to its surroundings with
# time, then it is called in motion.
# B.
# Rest
# 1.   If an object does not change its position with respect to its
# surroundings with time, then it is called at rest.
# Rest and motion are relative states. It means an object which is at rest
# in one frame of reference can be in motion in another frame of
# reference at the same time.
#
# 2.   Point Object An object can be considered as a point object, if the distance travelled
# by it is very large in comparison to its dimensions.
#
# C.
# Types of Motion
# 1. One Dimensional Motion
# If only one out of three coordinates specifying the position of the object
# changes with respect to time, then the motion is called one dimensional
# motion or rectilinear motion.
#
# For instance, motion of a block in a straight line, motion of a train
# along a straight track, a man walking on a level and narrow road and
# ...
